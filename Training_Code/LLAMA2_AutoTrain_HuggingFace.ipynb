# %%
# !pip install autotrain-advanced
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

#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

# %%
# !autotrain llm --train --project_name 'llama2_Constitution_Of_India' --model TinyPixel/Llama-2-7B-bf16-sharded --data_path nisaar/LLAMA2_Legal_Dataset_4.4k_Instructions --use_peft --use_int4 --learning_rate 2e-4 --train_batch_size 2 --num_train_epochs 4 --trainer sft --model_max_length 4000 --push_to_hub --repo_id nisaar/LLAMA2_Constitution_Of_India --block_size 4000 > training.log &

# %%
#Khatam Tata BBYE - DISCONNECT AND DELETE RUNTIME
from google.colab import runtime
runtime.unassign()
